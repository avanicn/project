# %% [raw]
# import pandas as pd
#
# # Load the dataset
# df = pd.read_csv("CICIDS2017_sample.csv")
#
# # Show the first few rows
# df.head()

# %%
# Check the column names and number of missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56661 entries, 0 to 56660
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Flow Duration                56661 non-null  int64
#  1   Total Fwd Packets            56661 non-null  int64
#  2   Total Backward Packets       56661 non-null  int64
#  3   Total Length of Fwd Packets  56661 non-null  int64
#  4   Total Length of Bwd Packets  56661 non-null  int64
#  5   Fwd Packet Length Max        56661 non-null  int64
#  6   Fwd Packet Length Min        56661 non-null  int64
#  7   Fwd Packet Length Mean       56661 non-null  float64
#  8   Fwd Packet Length Std        56661 non-null  float64
#  9   Bwd Packet Length Max        56661 non-null  int64
#  10  Bwd Packet Length Min        56661 non-null  int64
#  11  Bwd Packet Length Mean       56661 non-null  float64
#  12  Bwd Packet Length Std        56661 non-null  float64
#  13  Flow Bytes/s                 56607 non-null  float64
#  14  Flow Packets/s               56661 non-null  float64
#  15  Flow IAT Mean                56661 non-null  float64
#  16  Flow IAT Std                 56661 non-null  float64
#  17  Flow IAT Max                 56661 non-null  int64
#  18  Flow IAT Min                 56661 non-null  int64
#  19  Fwd IAT Total                56661 non-null  int64
#  20  Fwd IAT Mean                 56661 non-null  float64
#  21  Fwd IAT Std                  56661 non-null  float64
#  22  Fwd IAT Max                  56661 non-null  int64
#  23  Fwd IAT Min                  56661 non-null  int64
#  24  Bwd IAT Total                56661 non-null  int64
#  25  Bwd IAT Mean                 56661 non-null  float64
#  26  Bwd IAT Std                  56661 non-null  float64
#  27  Bwd IAT Max                  56661 non-null  int64
#  28  Bwd IAT Min                  56661 non-null  int64
#  29  Fwd PSH Flags                56661 non-null  int64
#  30  Bwd PSH Flags                56661 non-null  int64
#  31  Fwd URG Flags                56661 non-null  int64
#  32  Bwd URG Flags                56661 non-null  int64
#  33  Fwd Header Length            56661 non-null  int64
#  34  Bwd Header Length            56661 non-null  int64
#  35  Fwd Packets/s                56661 non-null  float64
#  36  Bwd Packets/s                56661 non-null  float64
#  37  Min Packet Length            56661 non-null  int64
#  38  Max Packet Length            56661 non-null  int64
#  39  Packet Length Mean           56661 non-null  float64
#  40  Packet Length Std            56661 non-null  float64
#  41  Packet Length Variance       56661 non-null  float64
#  42  FIN Flag Count               56661 non-null  int64
#  43  SYN Flag Count               56661 non-null  int64
#  44  RST Flag Count               56661 non-null  int64
#  45  PSH Flag Count               56661 non-null  int64
#  46  ACK Flag Count               56661 non-null  int64
#  47  URG Flag Count               56661 non-null  int64
#  48  CWE Flag Count               56661 non-null  int64
#  49  ECE Flag Count               56661 non-null  int64
#  50  Down/Up Ratio                56661 non-null  int64
#  51  Average Packet Size          56661 non-null  float64
#  52  Avg Fwd Segment Size         56661 non-null  float64
#  53  Avg Bwd Segment Size         56661 non-null  float64
#  54  Fwd Header Length.1          56661 non-null  int64
#  55  Fwd Avg Bytes/Bulk           56661 non-null  int64
#  56  Fwd Avg Packets/Bulk         56661 non-null  int64
#  57  Fwd Avg Bulk Rate            56661 non-null  int64
#  58  Bwd Avg Bytes/Bulk           56661 non-null  int64
#  59  Bwd Avg Packets/Bulk         56661 non-null  int64
#  60  Bwd Avg Bulk Rate            56661 non-null  int64
#  61  Subflow Fwd Packets          56661 non-null  int64
#  62  Subflow Fwd Bytes            56661 non-null  int64
#  63  Subflow Bwd Packets          56661 non-null  int64
#  64  Subflow Bwd Bytes            56661 non-null  int64
#  65  Init_Win_bytes_forward       56661 non-null  int64
#  66  Init_Win_bytes_backward      56661 non-null  int64
#  67  act_data_pkt_fwd             56661 non-null  int64
#  68  min_seg_size_forward         56661 non-null  int64
#  69  Active Mean                  56661 non-null  float64
#  70  Active Std                   56661 non-null  float64
#  71  Active Max                   56661 non-null  int64
#  72  Active Min                   56661 non-null  int64
#  73  Idle Mean                    56661 non-null  float64
#  74  Idle Std                     56661 non-null  float64
#  75  Idle Max                     56661 non-null  int64
#  76  Idle Min                     56661 non-null  int64
#  77  Label                        56661 non-null  object
# dtypes: float64(24), int64(53), object(1)
# memory usage: 33.7+ MB

# %%
# See which columns might be all 0 or not helpful
df.describe().T
# Out:
#                                count          mean           std  min   25%  \
# Flow Duration                56661.0  1.940740e+07  3.672377e+07  0.0  72.0
# Total Fwd Packets            56661.0  5.893348e+00  5.689868e+01  1.0   1.0
# Total Backward Packets       56661.0  5.441168e+00  6.651316e+01  0.0   1.0
# Total Length of Fwd Packets  56661.0  7.325051e+02  2.135208e+04  0.0   2.0
# Total Length of Bwd Packets  56661.0  5.282417e+03  1.092694e+05  0.0   0.0
# ...                              ...           ...           ...  ...   ...
# Active Min                   56661.0  6.484220e+04  6.835563e+05  0.0   0.0
# Idle Mean                    56661.0  1.474432e+07  3.214172e+07  0.0   0.0
# Idle Std                     56661.0  8.688159e+05  6.311718e+06  0.0   0.0
# Idle Max                     56661.0  1.539940e+07  3.301473e+07  0.0   0.0
# Idle Min                     56661.0  1.410650e+07  3.191101e+07  0.0   0.0
#
#                                  50%        75%          max
# Flow Duration                58897.0  8813192.0  119999998.0
# Total Fwd Packets                2.0        5.0       6930.0
# Total Backward Packets           2.0        5.0       9877.0
# Total Length of Fwd Packets     31.0      280.0    2866110.0
# Total Length of Bwd Packets     79.0     4830.0   21500000.0
# ...                              ...        ...          ...
# Active Min                       0.0        0.0  100000000.0
# Idle Mean                        0.0        0.0  119000000.0
# Idle Std                         0.0        0.0   68600000.0
# Idle Max                         0.0        0.0  119000000.0
# Idle Min                         0.0        0.0  119000000.0
#
# [77 rows x 8 columns]

# %%
# See what labels or attack types we have
df['Label'].value_counts()
# Out:
# Label
# BENIGN          22731
# DoS             19035
# PortScan         7946
# BruteForce       2767
# WebAttack        2180
# Bot              1966
# Infiltration       36
# Name: count, dtype: int64

# %%
# Convert labels to binary: 0 for BENIGN, 1 for any attack
df['Attack'] = df['Label'].apply(lambda x: 0 if x == 'BENIGN' else 1)

# %%
# Drop non-numeric and unnecessary columns
df = df.drop(['Label'], axis=1)

# Drop any columns with non-numeric data (just in case)
df = df.select_dtypes(include='number')

# Split into features and target
X = df.drop('Attack', axis=1)
y = df['Attack']

# %%
import numpy as np

# Replace inf/-inf with NaN
X.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN values
X.dropna(inplace=True)

# Make sure y matches the updated X
y = y[X.index]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Split data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train the model
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# See results
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6667
#            1       1.00      1.00      1.00     10307
#
#     accuracy                           1.00     16974
#    macro avg       0.99      1.00      0.99     16974
# weighted avg       1.00      1.00      1.00     16974

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y, cv=5)
print(scores)
print("Average accuracy:", scores.mean())
# Out:
# [0.78755744 0.99593496 0.48762814 0.94406151 0.9524567 ]
# Average accuracy: 0.8335277483209615

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.39      0.40      6816
#            1       0.60      0.61      0.60     10158
#
#     accuracy                           0.52     16974
#    macro avg       0.50      0.50      0.50     16974
# weighted avg       0.52      0.52      0.52     16974

# %%
print("Done. Report generated.")
print(classification_report(y_test, y_pred))
# Out:
# Done. Report generated.
#               precision    recall  f1-score   support
#
#            0       0.40      0.39      0.40      6816
#            1       0.60      0.61      0.60     10158
#
#     accuracy                           0.52     16974
#    macro avg       0.50      0.50      0.50     16974
# weighted avg       0.52      0.52      0.52     16974

# %%
import pandas as pd

# Convert to DataFrame (if not already)
df_train = pd.DataFrame(X_train)
df_test = pd.DataFrame(X_test)

# Check for any overlap
common = pd.merge(df_train, df_test, how='inner')
print(f"Number of duplicate rows between train and test: {len(common)}")
# Out:
# Number of duplicate rows between train and test: 321212

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# STEP 1: Clean the full dataset FIRST
X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.dropna(inplace=True)

# Align target (in case some rows dropped from X)
y = y.loc[X.index]

# STEP 2: Now do the train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, shuffle=True
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6667
#            1       1.00      1.00      1.00     10307
#
#     accuracy                           1.00     16974
#    macro avg       0.99      1.00      1.00     16974
# weighted avg       1.00      1.00      1.00     16974

# %%
y.value_counts(normalize=True)
# Out:
# Attack
# 1    0.598462
# 0    0.401538
# Name: proportion, dtype: float64

# %%
train_unique = X_train.drop_duplicates()
test_unique = X_test[~X_test.apply(tuple, axis=1).isin(train_unique.apply(tuple, axis=1))]

# %%
print(X_clean.columns)
# Out:
# Index(['Flow Duration', 'Total Fwd Packets', 'Total Backward Packets',
#        'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Min',
#        'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
#        'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Attack'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_clean = df.drop_duplicates()
X = X_clean.drop('Attack', axis=1)
y = X_clean['Attack']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

# %%
print(X_clean.columns)
# Out:
# Index(['Flow Duration', 'Total Fwd Packets', 'Total Backward Packets',
#        'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Min',
#        'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Flow Bytes/s',
#        'Flow Packets/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Total', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Total', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Length',
#        'Bwd Header Length', 'Fwd Packets/s', 'Bwd Packets/s',
#        'Min Packet Length', 'Max Packet Length', 'Packet Length Mean',
#        'Packet Length Std', 'Packet Length Variance', 'FIN Flag Count',
#        'SYN Flag Count', 'RST Flag Count', 'PSH Flag Count', 'ACK Flag Count',
#        'URG Flag Count', 'CWE Flag Count', 'ECE Flag Count', 'Down/Up Ratio',
#        'Average Packet Size', 'Avg Fwd Segment Size', 'Avg Bwd Segment Size',
#        'Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk',
#        'Fwd Avg Bulk Rate', 'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', 'Subflow Fwd Bytes',
#        'Subflow Bwd Packets', 'Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean',
#        'Idle Std', 'Idle Max', 'Idle Min', 'Attack'],
#       dtype='object')

# %%
# Drop duplicates first
X_clean = df.drop_duplicates()

# Separate features and label (corrected column name)
X = X_clean.drop('Attack', axis=1)
y = X_clean['Attack']

# Clean data: remove infinities and NaNs
import numpy as np
X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.dropna(inplace=True)

# Align y with cleaned X
y = y.loc[X.index]

# Split into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, shuffle=True
)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Train the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# %%
# Show precision, recall, F1-score, accuracy
print("📊 Classification Report:")
print(classification_report(y_test, y_pred))

# Optional: Show confusion matrix
print("🧮 Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6450
#            1       0.99      0.99      0.99      6763
#
#     accuracy                           0.99     13213
#    macro avg       0.99      0.99      0.99     13213
# weighted avg       0.99      0.99      0.99     13213
#
# 🧮 Confusion Matrix:
# [[6410   40]
#  [  57 6706]]

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(y_test, y_pred, display_labels=["Benign", "Attack"], cmap='Blues')

# %%
# Make predictions using your trained model
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Visual confusion matrix
disp = ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred,
    display_labels=["Benign", "Attack"],
    cmap='Blues',
    colorbar=True
)

# Add labels and display
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.grid(False)
plt.show()

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\avani\anaconda3\lib\site-packages (0.47.1)
# Requirement already satisfied: numpy in c:\users\avani\anaconda3\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\avani\anaconda3\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\avani\anaconda3\lib\site-packages (from shap) (1.5.1)
# Requirement already satisfied: pandas in c:\users\avani\anaconda3\lib\site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\avani\anaconda3\lib\site-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in c:\users\avani\anaconda3\lib\site-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.8 in c:\users\avani\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in c:\users\avani\anaconda3\lib\site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in c:\users\avani\anaconda3\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: typing-extensions in c:\users\avani\anaconda3\lib\site-packages (from shap) (4.11.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\avani\anaconda3\lib\site-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: colorama in c:\users\avani\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\avani\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\avani\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\avani\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\avani\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\avani\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\avani\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
import shap

# Create explainer for your trained tree-based model (e.g. RandomForest)
explainer = shap.TreeExplainer(model)

# %%
# Choose a small slice of your test set to keep it fast
X_sample = X_test[:100]

# %%
# Get SHAP values for the sample
shap_values = explainer.shap_values(X_sample)

# %%
# For binary classification, use shap_values[1] for the "Attack" class
shap.summary_plot(shap_values[1], X_sample, plot_type="dot")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[61], line 2
#       1 # For binary classification, use shap_values[1] for the "Attack" class
# ----> 2 shap.summary_plot(shap_values[1], X_sample, plot_type="dot")
#
# File ~\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:667, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     662         raise ValueError(
#     663             shape_msg + " Perhaps the extra column in the shap_values matrix is the "
#     664             "constant offset? Of so just pass shap_values[:,:-1]."
#     665         )
#     666     else:
# --> 667         assert num_features == features.shape[1], shape_msg
#     669 if feature_names is None:
#     670     feature_names = np.array([labels["FEATURE"] % str(i) for i in range(num_features)])
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.

# %%
print("X_sample shape:", X_sample.shape)
print("shap_values[1] shape:", shap_values[1].shape)
# Out:
# X_sample shape: (100, 77)
# shap_values[1] shape: (77, 2)

# %%
# Transpose SHAP values to match shape (100, 77)
shap_fixed = shap_values[1].T

# Plot it!
shap.summary_plot(shap_fixed, X_sample, plot_type="dot")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[65], line 5
#       2 shap_fixed = shap_values[1].T
#       4 # Plot it!
# ----> 5 shap.summary_plot(shap_fixed, X_sample, plot_type="dot")
#
# File ~\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:844, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     841 if vmin > vmax:  # fixes rare numerical precision issues
#     842     vmin = vmax
# --> 844 assert features.shape[0] == len(shaps), "Feature and SHAP matrices must have the same number of rows!"
#     846 # plot the nan values in the interaction feature as grey
#     847 nan_mask = np.isnan(values)
#
# AssertionError: Feature and SHAP matrices must have the same number of rows!

# %%
print("X_sample shape:", X_sample.shape)          # should be (100, 77)
print("shap_values[1] shape:", shap_values[1].shape)  # currently (77, 2)
# Out:
# X_sample shape: (100, 77)
# shap_values[1] shape: (77, 2)

# %%
# Fix the SHAP shape to match X_sample
shap_fixed = shap_values[1].T  # makes it (2, 77)

print("shap_fixed shape:", shap_fixed.shape)
# Out:
# shap_fixed shape: (2, 77)

# %%
import shap

# Use a tiny sample to keep SHAP fast and safe
X_sample = X_test[:10]  # Keep it very small to avoid shape bugs

# Recalculate SHAP values
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_sample)

# Print shape sanity check
print("X_sample shape:", X_sample.shape)
print("shap_values[1] shape:", shap_values[1].shape)

# Should now match: (10, number of features)
# Plot the summary
shap.summary_plot(shap_values[1], X_sample, plot_type="dot")
# Out:
# X_sample shape: (10, 77)
# shap_values[1] shape: (77, 2)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[71], line 16
#      12 print("shap_values[1] shape:", shap_values[1].shape)
#      14 # Should now match: (10, number of features)
#      15 # Plot the summary
# ---> 16 shap.summary_plot(shap_values[1], X_sample, plot_type="dot")
#
# File ~\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:667, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     662         raise ValueError(
#     663             shape_msg + " Perhaps the extra column in the shap_values matrix is the "
#     664             "constant offset? Of so just pass shap_values[:,:-1]."
#     665         )
#     666     else:
# --> 667         assert num_features == features.shape[1], shape_msg
#     669 if feature_names is None:
#     670     feature_names = np.array([labels["FEATURE"] % str(i) for i in range(num_features)])
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.

# %%
import shap

# Use a small sample for speed
X_sample = X_test[:10]

# Use the new SHAP explainer that handles this stuff better
explainer = shap.Explainer(model, X_sample)

# Compute SHAP values
shap_values = explainer(X_sample)

# Summary plot (will just work!)
shap.summary_plot(shap_values, X_sample)

# %%
import shap

# Sample just 100 rows to speed up computation
X_sample = X_test.sample(100, random_state=42)

# SHAP for tree models
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_sample)

# For binary classification: shap_values[1] is class "Attack"
print(f"SHAP values shape: {shap_values[1].shape}")
print(f"X_sample shape: {X_sample.shape}")

# Plot the summary
shap.summary_plot(shap_values[1], X_sample)
# Out:
# SHAP values shape: (77, 2)
# X_sample shape: (100, 77)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[75], line 15
#      12 print(f"X_sample shape: {X_sample.shape}")
#      14 # Plot the summary
# ---> 15 shap.summary_plot(shap_values[1], X_sample)
#
# File ~\anaconda3\Lib\site-packages\shap\plots\_beeswarm.py:667, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, use_log_scale, rng)
#     662         raise ValueError(
#     663             shape_msg + " Perhaps the extra column in the shap_values matrix is the "
#     664             "constant offset? Of so just pass shap_values[:,:-1]."
#     665         )
#     666     else:
# --> 667         assert num_features == features.shape[1], shape_msg
#     669 if feature_names is None:
#     670     feature_names = np.array([labels["FEATURE"] % str(i) for i in range(num_features)])
#
# AssertionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.

# %%
# Transpose from (features, classes) to (samples, features)
# Assuming you're using something like a LinearExplainer or kernel-based model

# Re-run SHAP value computation
explainer = shap.Explainer(model, X_sample)  # Automatically selects right explainer
shap_values = explainer(X_sample)  # NEW API returns an object with shap_values.values

# Print shapes to debug
print("SHAP values shape:", shap_values.values.shape)  # Should be (100, 77)
print("X_sample shape:", X_sample.shape)

# Plot with the new object (shap.Explanation)
shap.summary_plot(shap_values[..., 1], X_sample)
# Out:
# SHAP values shape: (100, 77, 2)
# X_sample shape: (100, 77)

# %%
shap.summary_plot(shap_values[..., 1], X_sample)

# %%
#Benchmarking

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Define models to benchmark
models = {
    "Random Forest": model,  # your trained RF model
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM": SVC()
}

# Evaluate each model
for name, clf in models.items():
    # Skip retraining Random Forest
    if name != "Random Forest":
        clf.fit(X_train, y_train)

    y_pred_bench = clf.predict(X_test)
    print(f"\n📊 {name} Performance:")
    print(classification_report(y_test, y_pred_bench))
# Out:
# 📊 Random Forest Performance:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6450
#            1       0.99      0.99      0.99      6763
#
#     accuracy                           0.99     13213
#    macro avg       0.99      0.99      0.99     13213
# weighted avg       0.99      0.99      0.99     13213
# C:\Users\avani\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 📊 Logistic Regression Performance:
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.77      6450
#            1       0.77      0.83      0.80      6763
#
#     accuracy                           0.79     13213
#    macro avg       0.79      0.79      0.79     13213
# weighted avg       0.79      0.79      0.79     13213
#
#
# 📊 SVM Performance:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      6450
#            1       0.92      0.81      0.86      6763
#
#     accuracy                           0.86     13213
#    macro avg       0.87      0.87      0.86     13213
# weighted avg       0.87      0.86      0.86     13213

# %%
import joblib

joblib.dump(model, 'random_forest_model.pkl')
# Out:
# ['random_forest_model.pkl']
